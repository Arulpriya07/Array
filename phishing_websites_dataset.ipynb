# %% [markdown]
# <a href="https://colab.research.google.com/github/Arulpriya07/Array/blob/main/phishing_websites_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-a94ca49e-869b-45ef-b943-b01899a53c51" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a94ca49e-869b-45ef-b943-b01899a53c51">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"phishing website url based dataset.xlsx")
data
# Out:
#                                                  URL   \
# 0                                    br-icloud.com.br
# 1                 mp3raid.com/music/krizz_kaliko.html
# 2                     bopsecrets.org/rexroth/cr/1.htm
# 3   http://www.garage-pirenne.be/index.php?option=...
# 4   http://adventure-nicaragua.net/index.php?optio...
# 5   http://buzzfil.net/m/show-art/ils-etaient-loin...
# 6      yourbittorrent.com/?q=anthony-hamilton-soulife
# 7        http://www.pashminaonline.com/pure-pashminas
# 8       allmusic.com/album/crazy-from-the-heat-r16990
# 9   corporationwiki.com/Ohio/Columbus/frank-s-bens...
# 10  http://www.ikenmijnkunst.nl/index.php/expositi...
# 11                     myspace.com/video/vid/30602581
# 12  http://www.lebensmittel-ueberwachung.de/index....
# 13  http://www.szabadmunkaero.hu/cimoldal.html?sta...
# 14   http://larcadelcarnevale.com/catalogo/palloncini
# 15       quickfacts.census.gov/qfd/maps/iowa_map.html
# ...

# %%
df=pd.DataFrame(data)
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        25 non-null     object
#  1   type: (bening/defacement)  20 non-null     object
#  2   PERCENT                    20 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 732.0+ bytes

# %%
df.describe()
# Out:
#          PERCENT
# count  20.000000
# mean    0.423000
# std     0.270771
# min     0.000000
# 25%     0.150000
# 50%     0.660000
# 75%     0.660000
# max     0.660000

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                                                  URL   \
# 0                                    br-icloud.com.br
# 1                 mp3raid.com/music/krizz_kaliko.html
# 2                     bopsecrets.org/rexroth/cr/1.htm
# 3   http://www.garage-pirenne.be/index.php?option=...
# 4   http://adventure-nicaragua.net/index.php?optio...
# 5   http://buzzfil.net/m/show-art/ils-etaient-loin...
# 6      yourbittorrent.com/?q=anthony-hamilton-soulife
# 7        http://www.pashminaonline.com/pure-pashminas
# 8       allmusic.com/album/crazy-from-the-heat-r16990
# 9   corporationwiki.com/Ohio/Columbus/frank-s-bens...
# 10  http://www.ikenmijnkunst.nl/index.php/expositi...
# 11                     myspace.com/video/vid/30602581
# 12  http://www.lebensmittel-ueberwachung.de/index....
# 13  http://www.szabadmunkaero.hu/cimoldal.html?sta...
# 14   http://larcadelcarnevale.com/catalogo/palloncini
# 15       quickfacts.census.gov/qfd/maps/iowa_map.html
# ...

# %%
df.isnull().sum()
# Out:
# URL                          0
# type: (bening/defacement)    5
# PERCENT                      5
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# dtype: bool

# %%
df.duplicated().sum(0)
# Out:
# np.int64(0)

# %%
df.dropna()
# Out:
#                                                  URL   \
# 0                                    br-icloud.com.br
# 1                 mp3raid.com/music/krizz_kaliko.html
# 3   http://www.garage-pirenne.be/index.php?option=...
# 4   http://adventure-nicaragua.net/index.php?optio...
# 5   http://buzzfil.net/m/show-art/ils-etaient-loin...
# 6      yourbittorrent.com/?q=anthony-hamilton-soulife
# 7        http://www.pashminaonline.com/pure-pashminas
# 8       allmusic.com/album/crazy-from-the-heat-r16990
# 9   corporationwiki.com/Ohio/Columbus/frank-s-bens...
# 11                     myspace.com/video/vid/30602581
# 12  http://www.lebensmittel-ueberwachung.de/index....
# 13  http://www.szabadmunkaero.hu/cimoldal.html?sta...
# 14   http://larcadelcarnevale.com/catalogo/palloncini
# 15       quickfacts.census.gov/qfd/maps/iowa_map.html
# 17     uk.linkedin.com/pub/steve-rubenstein/8/718/755
# 18               http://www.vnic.co/khach-hang.html\n
# ...

# %%
df.fillna("no record")
# Out:
#                                                  URL   \
# 0                                    br-icloud.com.br
# 1                 mp3raid.com/music/krizz_kaliko.html
# 2                     bopsecrets.org/rexroth/cr/1.htm
# 3   http://www.garage-pirenne.be/index.php?option=...
# 4   http://adventure-nicaragua.net/index.php?optio...
# 5   http://buzzfil.net/m/show-art/ils-etaient-loin...
# 6      yourbittorrent.com/?q=anthony-hamilton-soulife
# 7        http://www.pashminaonline.com/pure-pashminas
# 8       allmusic.com/album/crazy-from-the-heat-r16990
# 9   corporationwiki.com/Ohio/Columbus/frank-s-bens...
# 10  http://www.ikenmijnkunst.nl/index.php/expositi...
# 11                     myspace.com/video/vid/30602581
# 12  http://www.lebensmittel-ueberwachung.de/index....
# 13  http://www.szabadmunkaero.hu/cimoldal.html?sta...
# 14   http://larcadelcarnevale.com/catalogo/palloncini
# 15       quickfacts.census.gov/qfd/maps/iowa_map.html
# ...

# %%
df.fillna("no record", inplace=True)
# Out:
# /tmp/ipython-input-1558055460.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'no record' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("no record", inplace=True)

# %%
data
# Out:
#                                                  URL   \
# 0                                    br-icloud.com.br
# 1                 mp3raid.com/music/krizz_kaliko.html
# 2                     bopsecrets.org/rexroth/cr/1.htm
# 3   http://www.garage-pirenne.be/index.php?option=...
# 4   http://adventure-nicaragua.net/index.php?optio...
# 5   http://buzzfil.net/m/show-art/ils-etaient-loin...
# 6      yourbittorrent.com/?q=anthony-hamilton-soulife
# 7        http://www.pashminaonline.com/pure-pashminas
# 8       allmusic.com/album/crazy-from-the-heat-r16990
# 9   corporationwiki.com/Ohio/Columbus/frank-s-bens...
# 10  http://www.ikenmijnkunst.nl/index.php/expositi...
# 11                     myspace.com/video/vid/30602581
# 12  http://www.lebensmittel-ueberwachung.de/index....
# 13  http://www.szabadmunkaero.hu/cimoldal.html?sta...
# 14   http://larcadelcarnevale.com/catalogo/palloncini
# 15       quickfacts.census.gov/qfd/maps/iowa_map.html
# ...

# %%
df['PERCENT'].fillna(0)
# Out:
# 0           0.0
# 1          0.66
# 2     no record
# 3          0.15
# 4          0.66
# 5          0.66
# 6          0.66
# 7          0.15
# 8          0.66
# 9          0.66
# 10    no record
# 11         0.66
# 12         0.15
# 13         0.15
# 14         0.66
# 15         0.66
# 16    no record
# 17         0.15
# 18         0.15
# 19         0.66
# 20         0.15
# 21         0.15
# 22    no record
# 23    no record
# 24         0.66
# Name: PERCENT, dtype: object

# %%
data
# Out:
#                                                  URL   \
# 0                                    br-icloud.com.br
# 1                 mp3raid.com/music/krizz_kaliko.html
# 2                     bopsecrets.org/rexroth/cr/1.htm
# 3   http://www.garage-pirenne.be/index.php?option=...
# 4   http://adventure-nicaragua.net/index.php?optio...
# 5   http://buzzfil.net/m/show-art/ils-etaient-loin...
# 6      yourbittorrent.com/?q=anthony-hamilton-soulife
# 7        http://www.pashminaonline.com/pure-pashminas
# 8       allmusic.com/album/crazy-from-the-heat-r16990
# 9   corporationwiki.com/Ohio/Columbus/frank-s-bens...
# 10  http://www.ikenmijnkunst.nl/index.php/expositi...
# 11                     myspace.com/video/vid/30602581
# 12  http://www.lebensmittel-ueberwachung.de/index....
# 13  http://www.szabadmunkaero.hu/cimoldal.html?sta...
# 14   http://larcadelcarnevale.com/catalogo/palloncini
# 15       quickfacts.census.gov/qfd/maps/iowa_map.html
# ...

# %%
df['PERCENT'].fillna(0)
# Out:
# 0           0.0
# 1          0.66
# 2     no record
# 3          0.15
# 4          0.66
# 5          0.66
# 6          0.66
# 7          0.15
# 8          0.66
# 9          0.66
# 10    no record
# 11         0.66
# 12         0.15
# 13         0.15
# 14         0.66
# 15         0.66
# 16    no record
# 17         0.15
# 18         0.15
# 19         0.66
# 20         0.15
# 21         0.15
# 22    no record
# 23    no record
# 24         0.66
# Name: PERCENT, dtype: object

# %%
df['PERCENT'] = pd.to_numeric(df['PERCENT'], errors='coerce')
avg = df['PERCENT'].fillna(0).mean()
avg
# Out:
# np.float64(0.3384)

# %%
df['PERCENT'] = df['PERCENT'].fillna(avg)

# %%
df.to_csv("phishing websites dataset.csv")
files.download("phishing websites dataset.csv")

# %%
import matplotlib.pyplot as plt
plt.scatter(df["type: (bening/defacement)"],df["PERCENT"],color="maroon")
plt.title("phishing websites dataset")
plt.xlabel("type")
plt.ylabel("PERCENT")
# Out:
# Text(0, 0.5, 'PERCENT')

# %%
import matplotlib.pyplot as plt
plt.pie(df["PERCENT"], labels=df["type: (bening/defacement)"])
plt.title("phishing websites dataset")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df["PERCENT"])
plt.title("phishing websites dataset")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["PERCENT"])
plt.title("phishing websites dataset")
plt.xlabel("PERCENT Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.suptitle("phishing website dataset")
plt.subplot(2,2,1)

plt.scatter(df["type: (bening/defacement)"],df["PERCENT"],color="maroon")
plt.title("phishing websites dataset")
plt.xlabel("type")
plt.ylabel("PERCENT")
plt.subplot(2,2,2)

plt.pie(df["PERCENT"], labels=df["type: (bening/defacement)"])
plt.title("phishing websites dataset")

plt.subplot(2,2,3)

plt.plot(df["PERCENT"])
plt.title("phishing websites dataset")

plt.subplot(2,2,4)

plt.hist(df["PERCENT"])
plt.title("phishing websites dataset")
plt.xlabel("PERCENT Value")
plt.ylabel("Frequency")

plt.tight_layout() # Added to prevent labels from overlapping
plt.savefig("phishing.png")
plt.show()

# %%
files.download("phishing.png")
